# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/Users/sam/Downloads/trainer_state.csv")

# %%
train = df[pd.isna(df["eval_mrr"])]
eval = df[~pd.isna(df["eval_mrr"])]

# %%
train
# Out:
#       Unnamed: 0     loss  learning_rate  epoch    step  eval_mrr  \
# 0              0  11.1218   9.466667e-08   0.01     150       NaN
# 1              1   8.5697   1.946667e-07   0.01     300       NaN
# 2              2   5.9920   2.946667e-07   0.02     450       NaN
# 3              3   4.1849   3.946667e-07   0.02     600       NaN
# 4              4   3.0627   4.946667e-07   0.03     750       NaN
# ...          ...      ...            ...    ...     ...       ...
# 1070        1070   0.1761   3.792593e-08   6.08  149550       NaN
# 1071        1071   0.1486   2.681481e-08   6.08  149700       NaN
# 1072        1072   0.1653   1.570370e-08   6.09  149850       NaN
# 1073        1073   0.1470   4.592593e-09   6.09  150000       NaN
# 1075        1075      NaN            NaN   6.09  150000       NaN
#
#       eval_runtime  eval_samples_per_second  eval_steps_per_second  \
# 0              NaN                      NaN                    NaN
# ...

# %%
ax = sns.lineplot(data=train, y="loss", x="step")
sns.lineplot(data=eval, y="eval_mrr", x="step")
# Out:
# <Axes: xlabel='step', ylabel='loss'>

# %%
sns.lineplot(data=eval, y="eval_mrr", x="step")
# Out:
# <Axes: xlabel='step', ylabel='eval_mrr'>

# %%
eval.sort_values(by=["eval_mrr"], ascending=False).head(20)
# Out:
#       Unnamed: 0  loss  learning_rate  epoch    step  eval_mrr  eval_runtime  \
# 1031        1031   NaN            NaN   5.85  144000  0.935586      103.6967
# 973          973   NaN            NaN   5.53  136000  0.935494      103.4828
# 1002        1002   NaN            NaN   5.69  140000  0.935482      103.5406
# 988          988   NaN            NaN   5.61  138000  0.935390      103.4921
# 945          945   NaN            NaN   5.36  132000  0.935284      103.5071
# 1045        1045   NaN            NaN   5.93  146000  0.935271      103.7151
# 959          959   NaN            NaN   5.44  134000  0.935185      103.5281
# 887          887   NaN            NaN   5.04  124000  0.935169      103.6619
# 930          930   NaN            NaN   5.28  130000  0.934865      103.4500
# 1016        1016   NaN            NaN   5.77  142000  0.934787      103.6574
# 701          701   NaN            NaN   3.98   98000  0.934770      103.7354
# ...
